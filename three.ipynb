# %%
def lw(j):
    x=0
    for i in range(j):
        x=x+i
    print(x)

# %%
lw(10)
# Out:
# 45

# %%
# %timeit lw(10)
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# ...

# %%
# %load_ext line_profiler

# %%
# %lprun -f lw lw(100)
# Out:
# 4950

# %%
lw
# Out:
# <function __main__.lw(j)>

# %%
def lw25(k):
    z = k*(k+1)/2
    return z

# %%
lw25(3000)
# Out:
# 4501500.0

# %%
# %lprun -f lw25 lw25(10)
